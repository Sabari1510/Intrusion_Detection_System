# %%
# ==========================================================
# Import Required Libraries
# ==========================================================

import pandas as pd
import numpy as np
from pathlib import Path

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# # Phase 2 : Data Preprocessing
#
# ## Objectives
#
# - Load merged dataset
# - Remove duplicate records
# - Handle infinite values
# - Handle missing values
# - Clean column names
# - Save cleaned dataset

# %%
# ==========================================================
# Project Paths
# ==========================================================

PROJECT_DIR = Path(r"A:\Network-Intrusion-Detection-System")

DATASET_PATH = PROJECT_DIR / "dataset" / "cleaned" / "merged_dataset.csv"

print(DATASET_PATH)
# Out:
# A:\Network-Intrusion-Detection-System/dataset/cleaned/merged_dataset.csv

# %%
# ==========================================================
# Load Merged Dataset
# ==========================================================

merged_df = pd.read_csv(DATASET_PATH)

print("Dataset Loaded Successfully")

print(merged_df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 # ==========================================================
#       2 # Load Merged Dataset
#       3 # ==========================================================
#       4
# ----> 5 merged_df = pd.read_csv(DATASET_PATH)
#       6
#       7 print("Dataset Loaded Successfully")
#       8
#
# File /opt/tljh/user/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File /opt/tljh/user/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File /opt/tljh/user/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File /opt/tljh/user/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File /opt/tljh/user/lib/python3.12/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'A:\\Network-Intrusion-Detection-System/dataset/cleaned/merged_dataset.csv'

# %%
merged_df.columns = merged_df.columns.str.strip()

print("Column Names Cleaned")

# %%
merged_df.columns

# %%
before_rows = merged_df.shape[0]

merged_df = merged_df.drop_duplicates()

after_rows = merged_df.shape[0]

print(f"Rows Before : {before_rows}")

print(f"Rows After : {after_rows}")

print(f"Duplicates Removed : {before_rows-after_rows}")

# %%
merged_df.replace([np.inf,-np.inf],np.nan,inplace=True)

print("Infinite values converted to NaN")

# %%
merged_df.fillna(0,inplace=True)

print("Remaining Missing Values")

print(merged_df.isnull().sum().sum())

# %%
print("Dataset Shape")

print(merged_df.shape)

print()

print("Missing Values")

print(merged_df.isnull().sum().sum())

print()

print("Infinite Values")

print(np.isinf(
    merged_df.select_dtypes(include=[np.number])
).sum().sum())

# %%
OUTPUT_PATH = PROJECT_DIR / "dataset" / "cleaned" / "cleaned_cicids2017.csv"

merged_df.to_csv(OUTPUT_PATH,index=False)

print("Dataset Saved Successfully")

print(OUTPUT_PATH)

# %%
import torch

print(torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA H200 NVL

# %%
import os

print("CPU Cores:", os.cpu_count())
# Out:
# CPU Cores: 128

# %%
import psutil

ram = psutil.virtual_memory()

print("Total RAM:", round(ram.total / (1024**3), 2), "GB")
# Out:
# Total RAM: 503.53 GB

# %%
import os

print(os.getcwd())
# Out:
# /srv/data/datasets/Network-Intrusion-Detection-System/Intrusion_Detection_System/notebooks
